# %% [markdown]
# # Good Writing is High-Perplexity Compression
#
# Monday, April 14th, 2025

# %% [markdown]
# Great writing effectively compresses complex concepts into dense, high-impact prose -- balancing clarity and surprise. High-quality writing exhibits high perplexity per unit length. It continuously reshapes the reader's predictive model.

# %% [markdown]
# ## Why Perplexity? Why Compression?
#
# Exploring writing through the lens of computational linguistics and information theory.
#
# - Quick, clear definitions:
#     - Entropy
#     - Prediction
#     - Surprise
#
# - Connect the intuitive experience of writing as compression of ideas.
# - Good writing as the intersection of high-perplexity and effective compression.
#
# Writing with high perplexity means continuously challenging your readers' expectations. When a sentence genuinely surprises you, it alters your mental model, rather than merely confirming it, or adding new data points.
#
#
# Example: Compare two sentences -- one predictable, one surprising -- to intuitively illustrate perplexity.

# %% [markdown]
# ## A Perplexity-Based Evaluation of Writing
#
# - Select excerpts from:
#     - Fiction:
#         - McCarthy
#         - Kafka
#     - Non-Fiction:
#         - David Foster Wallace
#         - Nietzsche
# - Calculate perplexity using a pretrained LM.
# - Visualize perplexity scores
#
# Reflection:
# - Does higher perlexity actually align with perceived quality?
# - Discuss the limits -- why perplexity alone isn't sufficient, but is still intersting.
#
# Maybe rank Lex Fridman Podcast episode transcripts by the measure of the guest's perplexity and see what can be gleaned.

# %% [markdown]
# ## Compression: Is Shorter Always Better?
#
# - Several sentences of varying length but same meaning.
# - Measure perplexity and semantic similarity to quantify conceptual compression.
# - Analyze and clearly illustrate where brevity increases perplexity/impact, and where it might damage coherence.
# - Highlight that meaningful writing finds equilibrium between brevity and surprise.

# %%
## Conceptual Crossroads

- Pool embeddings from conceptually distant yet metaphorically connected terms.
- Identify and visualize centroids to reveal hidden conceptual bridges.
- Discuss how high-perplexity writing intentionally creates unexpected conceptual crossroads.
- Use metaphors deliberately to create novel cognitive pathways for your readers.

- Entropy heatmaps: Visualizing the density of sentences or paragraphs.
- Predictive surprise analysis: Quantifying how text shifts the reader's predictive model.
- Embedding drift over multiple drafts: Can revisions measurable change perplexity or concept centroids meaningfully?

# %% [markdown]
# ## Writing as Intentional Craft
#
# - Writing isn't *just* a compuational puzzle -- but thinking this way gives you fresh tools and perspectives.
# - Writers don't need constant quantification, but periodic deep dives can meaningfully shift their understanding.
# - Call to action:
#     - Try one small experiment: Measure perplexity on your favorite and least favorite paragraphs you've written. What surprises you?
